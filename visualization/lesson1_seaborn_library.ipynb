# %% [markdown]
# <a href="https://colab.research.google.com/github/SHermukhammadjon/Mohirdev_Data_Science_praktikum/blob/main/visualization/lesson1_seaborn_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/museum_visitors.csv", index_col = 0)
df.head(5)
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
df.shape
# Out:
# (59, 4)

# %%
sns.lineplot(data = df)

plt.show()

# %%
plt.plot(df)
plt.show()

# %%
df.columns
# Out:
# Index(['Avila Adobe', 'Firehouse Museum', 'Chinese American Museum',
#        'America Tropical Interpretive Center'],
#       dtype='object')

# %%
plt.figure(figsize = (17, 6))
plt.title("Museum visite count")

plt.xlabel("date")
plt.ylabel("pearson count")

plt.xticks(rotation = 90)
plt.grid()

sns.lineplot(data = df)

plt.show()
