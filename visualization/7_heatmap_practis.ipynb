# %% [markdown]
# <a href="https://colab.research.google.com/github/SHermukhammadjon/Mohirdev_Data_Science_praktikum/blob/main/visualization/7_heatmap_practis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 2-AMALIYOT. `seaborn`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1-VAZIFA. Avvalgi [amaliyotda](https://colab.research.google.com/drive/1jzhJ1gN6msILYOHaG2fhBBvUGaa4tcLf?usp=sharing) saqlangan faylni yangi `df`ga o'qing

# %%
#JAVOBINGIZNI SHU YERGA YOZING
df = pd.read_csv("https://drive.google.com/uc?id=1ZA3nKY-FGf5Dq5fSJ1Nr-gUxB0E1XZIs", index_col = 0)

# %%
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
df.shape
# Out:
# (33, 10)

# %%
#@title Misol:

# %% [markdown]
# ### 2-VAZIFA. `df` barcha ustunlarini chiziqli grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING
# plt.figure(figsize = (15, 6))

plt.figure(figsize = (16, 6))
sns.lineplot(data = df)
plt.show()

# %%
#@title Javob
plt.figure(figsize=(16,6))
sns.lineplot(data=df)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Grafiklar nomini to'g'rilang (`T`, `Tm` va hokazo matnlarni o'zbek tilida chiqaring.)

# %%
describe = pd.read_html("https://en.tutiempo.net/climate/ws-384570.html")[4]
describe.index = describe[0].values
describe.drop(0,  axis = 1, inplace = True)
describe.drop(['PP'], axis = 0, inplace = True)
describe.rename(columns = {1 : "explaning"}, inplace = True)
describe
# Out:
#                              explaning
# T           Average annual temperature
# TM  Annual average maximum temperature
# Tm  Average annual minimum temperature
# V            Annual average wind speed
# RA            Number of days with rain
# SN            Number of days with snow
# TS           Number of days with storm
# FG                Number of foggy days
# TN         Number of days with tornado
# GR            Number of days with hail

# %%
describe.shape
# Out:
# (10, 1)

# %%
packegs = !pip freeze
if 'googletrans==3.1.0a0' not in packegs:
  ! pip install googletrans==3.1.0a0

from googletrans import Translator

def tarjimon(text):
  translator = Translator()
  return translator.translate(text, dest = 'uz').text

tarjimon("I'm a translator function!")
# Out:
# 'Men tarjimon funksiyasiman!'

# %%
describe['translation']  = [tarjimon(text) for text in describe['explaning'].values]
describe
# Out:
#                              explaning                       translation
# T           Average annual temperature           O'rtacha yillik harorat
# TM  Annual average maximum temperature  Yillik o'rtacha maksimal harorat
# Tm  Average annual minimum temperature   O'rtacha yillik minimal harorat
# V            Annual average wind speed    Yillik o'rtacha shamol tezligi
# RA            Number of days with rain             Yomg'irli kunlar soni
# SN            Number of days with snow                 Qorli kunlar soni
# TS           Number of days with storm              Bo'ronli kunlar soni
# FG                Number of foggy days               Tumanli kunlar soni
# TN         Number of days with tornado         Tornado bilan kunlar soni
# GR            Number of days with hail       Do'l yog'adigan kunlar soni

# %%
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
df.shape
# Out:
# (33, 10)

# %%
#JAVOBINGIZNI SHU YERGA YOZING

plt.figure(figsize = (14, 6))
sns.lineplot(data = df)
plt.legend(title = "Tarif:", labels = describe['translation'])
plt.show()

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df, linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 4-VAZIFA. Yuqoridagi grafikda turli ko'rsatkichlar aralashib ketdi. Keling ustun turiga qarab alohida grafiklar chizamiz.
#
# #### 4.1. Haroratni ko'rsatuvchi ustunlarni alohida chiziqli grafik qilib chiqaring.

# %%
describe
# Out:
#                              explaning                       translation
# T           Average annual temperature           O'rtacha yillik harorat
# TM  Annual average maximum temperature  Yillik o'rtacha maksimal harorat
# Tm  Average annual minimum temperature   O'rtacha yillik minimal harorat
# V            Annual average wind speed    Yillik o'rtacha shamol tezligi
# RA            Number of days with rain             Yomg'irli kunlar soni
# SN            Number of days with snow                 Qorli kunlar soni
# TS           Number of days with storm              Bo'ronli kunlar soni
# FG                Number of foggy days               Tumanli kunlar soni
# TN         Number of days with tornado         Tornado bilan kunlar soni
# GR            Number of days with hail       Do'l yog'adigan kunlar soni

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize = (14, 6))
sns.lineplot(data = df.iloc[:,:3])
plt.legend(title = "Tarif:", labels = [tarjimon(i) for i in describe['explaning'].values[:3]])

plt.show()

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        # "Yomg'irli kunlar soni",
        # "Bo'ronli kunlar soni",
        # "Tumanli kunlar soni",
        # "To'fonli kunlar soni",
        # "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['T','TM','Tm']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# #### 4.2. Kunlarni ko'rsatuvchi ustunlarni alohida grafik ko'rinishida chiqaring

# %%
describe
# Out:
#                                   explaning  \
# T                Average annual temperature
# TM       Annual average maximum temperature
# Tm       Average annual minimum temperature
# PP  Rain or snow precipitation total annual
# V                 Annual average wind speed
# RA                 Number of days with rain
# SN                 Number of days with snow
# TS                Number of days with storm
# FG                     Number of foggy days
# TN              Number of days with tornado
# GR                 Number of days with hail
#
#                                 translation
# T                   O'rtacha yillik harorat
# TM         Yillik o'rtacha maksimal harorat
# Tm          O'rtacha yillik minimal harorat
# PP  Yillik jami yomg'ir yoki qor yog'inlari
# V            Yillik o'rtacha shamol tezligi
# RA                    Yomg'irli kunlar soni
# SN                        Qorli kunlar soni
# TS                     Bo'ronli kunlar soni
# FG                      Tumanli kunlar soni
# TN                Tornado bilan kunlar soni
# GR              Do'l yog'adigan kunlar soni

# %%
df.loc[:,['RA', 'SN', 'TS', 'FG', 'GR']].head()
# Out:
#         RA    SN    TS    FG   GR
# Year
# 1991  77.0  26.0  15.0  17.0  1.0
# 1992  93.0  19.0   9.0   2.0  1.0
# 1993  98.0  38.0  12.0  10.0  0.0
# 1994  66.0  28.0   4.0   9.0  0.0
# 1995  41.0  20.0   8.0  12.0  0.0

# %%
#JAVOBINGIZNI SHU YERGA YOZING

plt.figure(figsize = (14, 6))
sns.lineplot(data = df.loc[:,['RA', 'SN', 'TS', 'FG', 'GR']])
plt.legend(title = "Tarif:", labels = describe.loc[['RA', 'SN', 'TS', 'FG', 'GR'],'translation'].values)

plt.title("Toshkent shaxri kunlar soni")
plt.ylabel("Kunlar")
plt.xlabel("Yillar")

plt.show()

# %%
#@title Kutilgan natija:
labels=[
        # "Yillik o'rtacha harorat",
#         "Yillik o'rtacha maksimal harorat",
#         "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar soni"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['RA','SN','TS','FG','TN']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Kunlar")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 5-VAZIFA. Yillik o'rtacha shamol tezligini ustunli grafik ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize = (15, 6))

sns.barplot(data = df, y = 'V', x = df.index)

plt.title('Toshkent shaxri uchun o\'rtacha shamol tezligi')
plt.xlabel("Yil")
plt.ylabel("Tezlik")
plt.xticks(rotation = 90)

plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(16,6))
sns.barplot(x=df.index, y=df['V'])
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.ylabel("O'rtacha shamol tezligi (km/soat)")
plt.xlabel("Yillar")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 6-VAZIFA. Yomg'rili, qorli, bo'ronli, tumanli va do'l yoqqan kunlar sonini heatmap ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
#@title Kutilgan natija:
plt.figure(figsize=(30,5))
sns.heatmap(data=df[['RA','SN','TS','FG','GR']].T, cmap="YlGnBu", linewidths=1, square=True)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
yticks_labels = ["Yomg'ir","Qor","Bo'ron","Tuman","Do'l"]
plt.yticks(np.arange(5)+0.5, labels=yticks_labels)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
